# %%
import sys
# !{sys.executable} -m pip install yfinance

import yfinance as yf
from datetime import datetime
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 154.6 kB/s  0:00:18 eta 0:00:01
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15636 sha256=1f7f4748df0b8841d985553d089cc6dcebac9f3b01672309cc8441d29629a9eb
#   Stored in directory: /Users/premsai/Library/Caches/pip/wheels/42/d6/84/bf57a755f4569494cd00de4bb46ef064874823f4d19c82e960
# Successfully built multitasking
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [yfinance]7/9 [beautifulsoup4]
# ...

# %%
df = yf.download('MSFT',start='2020-01-01', end=datetime.today())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.sort_index
# Out:
# <bound method DataFrame.sort_index of Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2020-01-02  152.505661  152.610105  150.331356  150.758619  22622100
# 2020-01-03  150.606705  151.869516  150.074998  150.321872  21116200
# 2020-01-06  150.996033  151.062503  148.603335  149.144547  20813700
# 2020-01-07  149.619278  151.603691  149.372418  151.271381  21634100
# 2020-01-08  152.002472  152.676610  149.970582  150.901070  27746500
# ...                ...         ...         ...         ...       ...
# 2026-01-09  479.279999  479.820007  472.200012  474.059998  18491000
# 2026-01-12  477.179993  480.989990  475.679993  476.670013  23519900
# 2026-01-13  470.670013  475.779999  465.950012  474.679993  28545800
# 2026-01-14  459.380005  468.200012  457.170013  466.459991  28154700
# 2026-01-15  460.049988  464.119995  457.529999  466.345001   9231286
#
# [1518 rows x 5 columns]>

# %%
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2026-01-09  479.279999  479.820007  472.200012  474.059998  18491000
# 2026-01-12  477.179993  480.989990  475.679993  476.670013  23519900
# 2026-01-13  470.670013  475.779999  465.950012  474.679993  28545800
# 2026-01-14  459.380005  468.200012  457.170013  466.459991  28154700
# 2026-01-15  460.049988  464.119995  457.529999  466.345001   9231286

# %%
#maximum price of the share 
a=df.loc['2020-01-02':'2026-01-09']["High"].idxmax()
df.loc[a]
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2025-07-31  531.629395  553.502444  530.035029  553.283183  51617300

# %%
df["High"].idxmax()
# Out:
# Ticker
# MSFT   2025-07-31
# dtype: datetime64[ns]

# %%
df["Low"].idxmin()
# Out:
# Ticker
# MSFT   2020-03-23
# dtype: datetime64[ns]
